# %% [markdown]
# # Mapa interativo das capitais do Brasil
#
# Integrantes:
#
# - Luiz Henrique
# - Paulo Henrique
#
# ## Objetivo do trabalho
#
# Integrar todos os conceitos trabalhados pelos grupos anteriores.

# %% [markdown]
# ## 1) Bibliotecas usadas
#
# Usamos as seguintes bibliotecas `pandas`, `folium` para criar o mapa.

# %%
# %pip install pandas 
# %pip install folium
# Out:
# Requirement already satisfied: pandas in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pichau\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\pichau\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from folium) (2.4.6)
# Requirement already satisfied: requests in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from folium) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\pichau\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->folium) (2026.5.20)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import folium

# %% [markdown]
# ## 2) leitura do arquivo CSV
#
# O arquivo CSV é a nossa base de dados que foi feita com dados do ibge.

# %%
df = pd.read_csv("capitais_brasil_ibge.csv")

df.head()
# Out:
#       capital  uf    estado    regiao  latitude  longitude  \
# 0  Rio Branco  AC      Acre     Norte  -9.97499   -67.8243
# 1      Maceió  AL   Alagoas  Nordeste  -9.66599   -35.7350
# 2      Macapá  AP     Amapá     Norte   0.03493   -51.0694
# 3      Manaus  AM  Amazonas     Norte  -3.11866   -60.0212
# 4    Salvador  BA     Bahia  Nordeste -12.97140   -38.5014
#
#                                                fonte  \
# 0  IBGE - Localidades do Brasil / Censo Demográfi...
# 1  IBGE - Localidades do Brasil / Censo Demográfi...
# 2  IBGE - Localidades do Brasil / Censo Demográfi...
# 3  IBGE - Localidades do Brasil / Censo Demográfi...
# 4  IBGE - Localidades do Brasil / Censo Demográfi...
#
#                                           link_fonte
# 0  https://www.ibge.gov.br/geociencias/organizaca...
# 1  https://www.ibge.gov.br/geociencias/organizaca...
# 2  https://www.ibge.gov.br/geociencias/organizaca...
# 3  https://www.ibge.gov.br/geociencias/organizaca...
# 4  https://www.ibge.gov.br/geociencias/organizaca...

# %% [markdown]
# ## 3) entendendo a estrutura dos dados
#
# - Aqui vamos entender a tabela.
#
#     - quantidade de linhas e colunas
#     - nomes das colunas
#     - os tipos dos dados
#     - se tem valores vazios

# %%
print("linhas e colunas:", df.shape)

print("\ncolunas da tabela:")
print(df.columns)

print("\ntipos dos dados:")
print(df.dtypes)

print("\nvalores vazios por coluna:")
print(df.isnull().sum())
# Out:
# linhas e colunas: (27, 8)
#
# colunas da tabela:
# Index(['capital', 'uf', 'estado', 'regiao', 'latitude', 'longitude', 'fonte',
#        'link_fonte'],
#       dtype='str')
#
# tipos dos dados:
# capital           str
# uf                str
# estado            str
# regiao            str
# latitude      float64
# longitude     float64
# fonte             str
# link_fonte        str
# dtype: object
#
# valores vazios por coluna:
# capital       0
# uf            0
# estado        0
# regiao        0
# latitude      0
# longitude     0
# fonte         0
# link_fonte    0
# dtype: int64

# %% [markdown]
# # 4) filtro por região
#
# Aqui vamos criar um filtro para visualizar apenas as capitais de uma região.
#
# Você pode trocar o valor de `regiao_escolhida` para:
#
# - Sul -------------> 3 estados
# - Norte ----------> 7 estados
# - Sudeste -------> 4 estados
# - Nordeste ------> 9 estados
# - Centro-Oeste -> 4 estados

# %%
# escolhemos a região
regiao_escolhida = "Centro-Oeste"

# faz um novo df apenas com a região escolhida
df_filtrado = df[df["regiao"] == regiao_escolhida]

# aqui mostrar o resultado
df_filtrado
# Out:
#          capital  uf              estado        regiao  latitude  longitude  \
# 6       Brasília  DF    Distrito Federal  Centro-Oeste  -15.7939   -47.8828
# 8        Goiânia  GO               Goiás  Centro-Oeste  -16.6864   -49.2643
# 10        Cuiabá  MT         Mato Grosso  Centro-Oeste  -15.6010   -56.0974
# 11  Campo Grande  MS  Mato Grosso do Sul  Centro-Oeste  -20.4486   -54.6295
#
#                                                 fonte  \
# 6   IBGE - Localidades do Brasil / Censo Demográfi...
# 8   IBGE - Localidades do Brasil / Censo Demográfi...
# 10  IBGE - Localidades do Brasil / Censo Demográfi...
# 11  IBGE - Localidades do Brasil / Censo Demográfi...
#
#                                            link_fonte
# 6   https://www.ibge.gov.br/geociencias/organizaca...
# 8   https://www.ibge.gov.br/geociencias/organizaca...
# 10  https://www.ibge.gov.br/geociencias/organizaca...
# 11  https://www.ibge.gov.br/geociencias/organizaca...

# %% [markdown]
# ## 5) criando o mapa interativo com folium
#
# ### o que faz o folium
#
# - ele é uma biblioteca Python usada para criar mapas interativos, permitindo adicionar marcadores, pop-ups e camadas no mapa.

# %%
# aqui acontece a criação do mapa centralizado no Brasil
mapa = folium.Map(
    location=[-14.2350, -51.9253],
    zoom_start=4
)

# adicionamos capitais como um marcador no mapa
for linha in df.itertuples():

    # aqui faremos o que vai aparecer quando clicar no marcador
    texto_popup = f"""
    <b>{linha.capital}</b><br>
    Estado: {linha.estado}<br>
    UF: {linha.uf}<br>
    Região: {linha.regiao}<br>
    Latitude: {linha.latitude}<br>
    Longitude: {linha.longitude}
    """

    # fizemos o marcador no mapa
    folium.Marker(
        location=[linha.latitude, linha.longitude],
        popup=texto_popup,
        tooltip=linha.capital
    ).add_to(mapa)

# mostra a pre-visualização
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b9ef00bebadc54eff538e103b3dda03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b9ef00bebadc54eff538e103b3dda03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b9ef00bebadc54eff538e103b3dda03 = L.map(
#                 &quot;map_8b9ef00bebadc54eff538e103b3dda03&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27e78f3a6ff860532358176a6a335cde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27e78f3a6ff860532358176a6a335cde.addTo(map_8b9ef00bebadc54eff538e103b3dda03);
#
#
#             var marker_22948f76825d605e433bc1b6efac28ee = L.marker(
#                 [-9.97499, -67.8243],
#                 {
# }
#             ).addTo(map_8b9ef00bebadc54eff538e103b3dda03);
#
#
#         var popup_08c6685f013a7beb5357246c68799d25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc941abcae053fd6967bcbefcc5976b0 = $(`&lt;div id=&quot;html_bc941abcae053fd6967bcbefcc5976b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Rio Branco&lt;/b&gt;&lt;br&gt;     Estado: Acre&lt;br&gt;     UF: AC&lt;br&gt;     Região: Norte&lt;br&gt;     Latitude: -9.97499&lt;br&gt;     Longitude: -67.8243     &lt;/div&gt;`)[0];
#                 popup_08c6685f013a7beb5357246c68799d25.setContent(html_bc941abcae053fd6967bcbefcc5976b0);
#
#
#
#         marker_22948f76825d605e433bc1b6efac28ee.bindPopup(popup_08c6685f013a7beb5357246c68799d25)
#         ;
#
#
#
#
#             marker_22948f76825d605e433bc1b6efac28ee.bindTooltip(
#                 `&lt;div&gt;
#                      Rio Branco
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99e5702a1fa4bb1d614e4588f7a47ec6 = L.marker(
#                 [-9.66599, -35.735],
#                 {
# }
#             ).addTo(map_8b9ef00bebadc54eff538e103b3dda03);
#
#
#         var popup_b7a662c429c5930060ec98329e4866fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_566532ab784d3c12eab6224c0d688fff = $(`&lt;div id=&quot;html_566532ab784d3c12eab6224c0d688fff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Maceió&lt;/b&gt;&lt;br&gt;     Estado: Alagoas&lt;br&gt;     UF: AL&lt;br&gt;     Região: Nordeste&lt;br&gt;     Latitude: -9.66599&lt;br&gt;     Longitude: -35.735     &lt;/div&gt;`)[0];
#                 popup_b7a662c429c5930060ec98329e4866fe.setContent(html_566532ab784d3c12eab6224c0d688fff);
#
#
#
#         marker_99e5702a1fa4bb1d614e4588f7a47ec6.bindPopup(popup_b7a662c429c5930060ec98329e4866fe)
#         ;
#
#
#
#
#             marker_99e5702a1fa4bb1d614e4588f7a47ec6.bindTooltip(
#                 `&lt;div&gt;
#                      Maceió
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c86e1d86bb8d2bafdd39175adf1ef4ad = L.marker(
#                 [0.03493, -51.0694],
#                 {
# }
#             ).addTo(map_8b9ef00bebadc54eff538e103b3dda03);
#
#
#         var popup_519086bec1832e09d9aa2a3261bf9b23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fe06758cb85abcdc5b016812892282d = $(`&lt;div id=&quot;html_0fe06758cb85abcdc5b016812892282d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Macapá&lt;/b&gt;&lt;br&gt;     Estado: Amapá&lt;br&gt;     UF: AP&lt;br&gt;     Região: Norte&lt;br&gt;     Latitude: 0.03493&lt;br&gt;     Longitude: -51.0694     &lt;/div&gt;`)[0];
#                 popup_519086bec1832e09d9aa2a3261bf9b23.setContent(html_0fe06758cb85abcdc5b016812892282d);
#
#
#
#         marker_c86e1d86bb8d2bafdd39175adf1ef4ad.bindPopup(popup_519086bec1832e09d9aa2a3261bf9b23)
#         ;
#
#
#
#
#             marker_c86e1d86bb8d2bafdd39175adf1ef4ad.bindTooltip(
#                 `&lt;div&gt;
#                      Macapá
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9f213df8ac9cd34d5f17eb2caf778c15 = L.marker(
#                 [-3.11866, -60.0212],
#                 {
# }
#             ).addTo(map_8b9ef00bebadc54eff538e103b3dda03);
#
#
#         var popup_6b88cb52f984009c7aae279f0196d511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100

# %% [markdown]
# # 6) adicionando o filtro
#
# Aqui fizemos o mesmo codigo, no entanto adicionando os filtros

# %%
mapa_regioes = folium.Map(
    location=[-14.2350, -51.9253],
    zoom_start=4
)

# aqui faremos uma camada para cada região
for regiao in df["regiao"].unique():

    # usamos o FeatureGroup para conseguir criar um grupo de marcadores
    grupo_regiao = folium.FeatureGroup(name=regiao)

    # filtramos as capitais daquela região
    dados_regiao = df[df["regiao"] == regiao]

    # colocamos as capitais de suas respectivas regiões no grupo indicado a elas
    for linha in dados_regiao.itertuples():

        texto_popup = f"""
        <b>{linha.capital}</b><br>
        Estado: {linha.estado}<br>
        UF: {linha.uf}<br>
        Região: {linha.regiao}<br>
        Latitude: {linha.latitude}<br>
        Longitude: {linha.longitude}
        """

        folium.Marker(
            location=[linha.latitude, linha.longitude],
            popup=texto_popup,
            tooltip=linha.capital
        ).add_to(grupo_regiao)

    # adicionamos o grupo no mapa
    grupo_regiao.add_to(mapa_regioes)

# aqui temos o controle para mostrar ou nao determinada região no mapa
folium.LayerControl(collapsed=False).add_to(mapa_regioes)


mapa_regioes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c3ec7e04c612aecd74a1db54cf8669b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c3ec7e04c612aecd74a1db54cf8669b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c3ec7e04c612aecd74a1db54cf8669b = L.map(
#                 &quot;map_8c3ec7e04c612aecd74a1db54cf8669b&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf2d31025c3e7d79faceffcf3055468c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf2d31025c3e7d79faceffcf3055468c.addTo(map_8c3ec7e04c612aecd74a1db54cf8669b);
#
#
#             var feature_group_c1de51e67bd48b3dca0b867799ce381f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5ca1e843e1668356bbe6992e72df1ff2 = L.marker(
#                 [-9.97499, -67.8243],
#                 {
# }
#             ).addTo(feature_group_c1de51e67bd48b3dca0b867799ce381f);
#
#
#         var popup_ee9cb4924438343c7859adaf640241a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb0962fd577cc2a423409a29172e4307 = $(`&lt;div id=&quot;html_fb0962fd577cc2a423409a29172e4307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Rio Branco&lt;/b&gt;&lt;br&gt;         Estado: Acre&lt;br&gt;         UF: AC&lt;br&gt;         Região: Norte&lt;br&gt;         Latitude: -9.97499&lt;br&gt;         Longitude: -67.8243         &lt;/div&gt;`)[0];
#                 popup_ee9cb4924438343c7859adaf640241a5.setContent(html_fb0962fd577cc2a423409a29172e4307);
#
#
#
#         marker_5ca1e843e1668356bbe6992e72df1ff2.bindPopup(popup_ee9cb4924438343c7859adaf640241a5)
#         ;
#
#
#
#
#             marker_5ca1e843e1668356bbe6992e72df1ff2.bindTooltip(
#                 `&lt;div&gt;
#                      Rio Branco
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_773666638e8ae5071100914f4d7a439e = L.marker(
#                 [0.03493, -51.0694],
#                 {
# }
#             ).addTo(feature_group_c1de51e67bd48b3dca0b867799ce381f);
#
#
#         var popup_c45d09b7d7f8d47db2943b3fe9790782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9565f514043889e7b10dccd7f8d2f88 = $(`&lt;div id=&quot;html_f9565f514043889e7b10dccd7f8d2f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Macapá&lt;/b&gt;&lt;br&gt;         Estado: Amapá&lt;br&gt;         UF: AP&lt;br&gt;         Região: Norte&lt;br&gt;         Latitude: 0.03493&lt;br&gt;         Longitude: -51.0694         &lt;/div&gt;`)[0];
#                 popup_c45d09b7d7f8d47db2943b3fe9790782.setContent(html_f9565f514043889e7b10dccd7f8d2f88);
#
#
#
#         marker_773666638e8ae5071100914f4d7a439e.bindPopup(popup_c45d09b7d7f8d47db2943b3fe9790782)
#         ;
#
#
#
#
#             marker_773666638e8ae5071100914f4d7a439e.bindTooltip(
#                 `&lt;div&gt;
#                      Macapá
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d567c8b0e3d51c1ea92858d3bf85e673 = L.marker(
#                 [-3.11866, -60.0212],
#                 {
# }
#             ).addTo(feature_group_c1de51e67bd48b3dca0b867799ce381f);
#
#
#         var popup_165383b72098ceb9f90360443272d93e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d539a21e6375613453f224c8a660456 = $(`&lt;div id=&quot;html_2d539a21e6375613453f224c8a660456&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Manaus&lt;/b&gt;&lt;br&gt;         Estado: Amazonas&lt;br&gt;         UF: AM&lt;br&gt;         Região: Norte&lt;br&gt;         Latitude: -3.11866&lt;br&gt;         Longitude: -60.0212         &lt;/div&gt;`)[0];
#                 popup_165383b72098ceb9f90360443272d93e.setContent(html_2d539a21e6375613453f224c8a660456);
#
#
#
#         marker_d567c8b0e3d51c1ea92858d3bf85e673.bindPopup(popup_165383b72098ceb9f90360443272d93e)
#         ;
#
#
#
#
#             marker_d567c8b0e3d51c1ea92858d3bf85e673.bindTooltip(
#                 `&lt;div&gt;
#                      Manaus
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0585320af4996574135877970524

# %% [markdown]
# ## 7) Conclusão
#
# Criamos um mapa interativo das capitais brasileiras usando dados de um arquivo CSV.
#
# ## O que fizemos
# - Carregamos uma base de dados em CSV
# - Entendemos a estrutura dos dados
# - Criamos filtros por região
# - Criamos um mapa interativo com folium
